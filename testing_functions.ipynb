# %%
import torch
# FROM LAB 9 #
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cpu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install opencv-python==4.4.0.46

# %%
import os

## FROM LABS ##
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/Computer Vision/Coursework/' 
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Computer Vision/Coursework')
# Out:
# ['CW_Dataset-2.zip', 'Untitled0.ipynb', 'EmotionRecognition.py', '__pycache__', 'ASARJOU_CV_VIDEO.avi', 'ASARJOU_CV_VIDEO-3.avi', 'ASARJOU_CV_CW_SHORT.mp4', 'ASARJOU_CV_CW_SHORT.avi', 'train_lab.csv', 'val_lab.csv', 'fin_MLP_ADASYN.pkl', 'fin_CNN.pkl', 'fin_SIFT_MLP.pkl', 'fin_HOG_MLP.pkl', 'fin_HOG_MLP', 'fin_CNN', 'fin_CNN.pth', 'fin_SIFT_MLP.pth', 'fin_HOG_MLP.pth', 'MLP.py']

# %%
from EmotionRecognition import EmotionRecognition, EmotionRecognitionVideo

import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from torchvision.io import read_image
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from torchvision.transforms import ToTensor, Lambda
import time
import pandas as pd
import copy
from PIL import Image
from skimage import io
from MLP import MLP
from skimage.feature import hog
from skimage import data, exposure
from torch.utils.data import TensorDataset
from skimage.measure import label, regionprops
from matplotlib import rc
import matplotlib.animation as animation
from matplotlib import patches

import os
import pickle
# Out:
# ['CW_Dataset-2.zip', 'Untitled0.ipynb', 'EmotionRecognition.py', '__pycache__', 'ASARJOU_CV_VIDEO.avi', 'ASARJOU_CV_VIDEO-3.avi', 'ASARJOU_CV_CW_SHORT.mp4', 'ASARJOU_CV_CW_SHORT.avi', 'train_lab.csv', 'val_lab.csv', 'fin_MLP_ADASYN.pkl', 'fin_CNN.pkl', 'fin_SIFT_MLP.pkl', 'fin_HOG_MLP.pkl', 'fin_HOG_MLP', 'fin_CNN', 'fin_CNN.pth', 'fin_SIFT_MLP.pth', 'fin_HOG_MLP.pth', 'MLP.py']

# %%
# Identify path to zipped dataset
###TAKEN FROM LAB 9 ###
#zip_path = os.path.join(GOOGLE_DRIVE_PATH, 'CW_Dataset-2.zip')

# Copy it to Colab
#!cp '{zip_path}' .

# Unzip it (removing useless files stored in the zip)
#!yes|unzip -q CW_Dataset-2.zip

# Delete zipped version from Colab (not from Drive)
#!rm CW_Dataset-2.zip

# %%
path_to_testset = "CW_Dataset-2"

# %%
EmotionRecognition.EmotionRecognition(path_to_testset, "SIFT")

## TAKES INPUT: "SIFT", "HOGS" or "CNN"
# Out:
# test loss: 1.2611 test acc: 0.2771

# %%
EmotionRecognition.EmotionRecognition(path_to_testset, "HOGS")
# Out:
# test loss: 0.9790 test acc: 0.6640

# %%
EmotionRecognition.EmotionRecognition(path_to_testset, "CNN")
# Out:
# test loss: 0.6533 test acc: 0.8214

# %%
a = EmotionRecognitionVideo.EmotionRecognitionVideo('ASARJOU_CV_CW_SHORT.avi')

# %%
a
